# %% [markdown]
# ### List
#
# * [ ]와 ,로 표현하는 데이터 형으로 여러 가지 형태의 정보를 하나의 리스트로 묶어서 나타냄

# %%
squares = [1, 4, 9, 16, 25]
zoo_animal = ['tiger', 'lion', 'monkey']
smith_information = ['Smith', 1990, 'London']
lee_information = ['Lee', 1975, 'Seoul']
customer = [smith_information, lee_information]

# %% [markdown]
# * len() 함수를 이용하여 길이를 구함

# %%
len(squares)
# Out:
# 5

# %%
len(zoo_animal)
# Out:
# 3

# %%
len(customer)
# Out:
# 2

# %% [markdown]
# ### List의 인덱스(index)

# %%
squares = [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# * index를 이용한 list 접근
#   * 첫 아이템의 index는 0부터 시작

# %%
squares[0]
# Out:
# 1

# %%
squares[1]
# Out:
# 4

# %%
squares[4]
# Out:
# 25

# %% [markdown]
# ### list의 slice 연산

# %%
squares = [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
squares[0:3]
# Out:
# [1, 4, 9]

# %% [markdown]
# 혹은

# %%
squares[:3]
# Out:
# [1, 4, 9]

# %% [markdown]
#   * 인덱스 0의 item부터 인덱스 3의 item 이전까지

# %%
squares[3:6]
# Out:
# [16, 25, 36]

# %% [markdown]
#   * 인덱스 3의 item부터 인덱스 6의 item 이전까지

# %%
squares[6:9]
# Out:
# [49, 64, 81]

# %% [markdown]
# 혹은

# %%
squares[6:]
# Out:
# [49, 64, 81]

# %% [markdown]
# * 인덱스 0의 item부터 인덱스 6의 item 이전까지 2의 간격으로

# %%
squares[0:6:2]
# Out:
# [1, 9, 25]

# %% [markdown]
# ### list 내용 변경

# %%
squares = [1, 4, 10, 17, 25]

# %%
squares[2] = 9
print squares
# Out:
# [1, 4, 9, 17, 25]

# %%
squares[3] = 16
print squares
# Out:
# [1, 4, 9, 16, 25]

# %%
squares = [1, 4, 10, 17, 25]
print squares
# Out:
# [1, 4, 10, 17, 25]

# %%
squares[2:4] = [9, 16]
print squares
# Out:
# [1, 4, 9, 16, 25]

# %%
squares = squares + [36, 49, 64]
print squares
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
squares.append(81)
print squares
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
squares.append(10**2)
print squares
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
squares[5:10] = []
print squares
# Out:
# [1, 4, 9, 16, 25]

# %%
squares[1] = []
print squares
# Out:
# [1, [], 9, 16, 25]

# %%
squares[1:2] = []
print squares
# Out:
# [1, 9, 16, 25]

# %%
squares.insert(1, 4)
print squares
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ### list내의 list

# %%
A = [[0,1,2,3,4], ['a', 'b']]

# %%
A[0]
# Out:
# [0, 1, 2, 3, 4]

# %%
A[1]
# Out:
# ['a', 'b']

# %%
A[0][0]
# Out:
# 0

# %%
A[0][1]
# Out:
# 1

# %%
A[1][0]
# Out:
# 'a'

# %%
A[1][1]
# Out:
# 'b'

# %% [markdown]
# ### list의 다양한 method

# %%
animals = ['dog', 'cat', 'duck', 'lion', 'snake']

# %%
animals.index('cat')
# Out:
# 1

# %%
animals.remove('duck')
animals
# Out:
# ['dog', 'cat', 'lion', 'snake']

# %% [markdown]
# * list data type은 다양한 method들을 포함하며 아래의 링크에서 확인
# * https://docs.python.org/2/tutorial/datastructures.html#more-on-lists
#
# ### 참조와 복사
#
# * 하나의 객체를 L1, L2가 동시에 지칭하여, L1의 원소가 변하면 L2의 원소도 같이 변함

# %%
L1 = [1, 2, 3]
L2 = L1
L1[0] = 4

# %%
print L1
# Out:
# [4, 2, 3]

# %%
print L2
# Out:
# [4, 2, 3]

# %% [markdown]
# ### 참조와 복사(2)
#
# * L1에 새로운 리스트를 대응하면 원래의 참조를 끊고 새로운 대입값을 적용

# %%
L1 = [1, 2, 3]
L2 = L1
L1 = [4, 5, 6]

# %%
print L1
# Out:
# [4, 5, 6]

# %%
print L2
# Out:
# [1, 2, 3]

# %% [markdown]
# ### 참조와 복사(3)
#
# * 같은 대상을 참조하는 것이 아니라 대상을 복사하여 사용하고 싶을 때

# %%
L1 = [1, 2, 3]
L2 = L1[:]

# %% [markdown]
# 혹은

# %%
L2 = list(L1)

# %%
L1[0] = 4
print L1
# Out:
# [4, 2, 3]

# %%
print L2
# Out:
# [1, 2, 3]

# %% [markdown]
# ### 복사의 예 (Cloning)
#
# 다음의 두 removeDup를 비교해 보자.

# %%
def removeDup(L1, L2):
    for e1 in L1:
        if e1 in L2:
            L1.remove(e1)
            
L1=[1,2,3,4]
L2=[1,2,5,6]
removeDup(L1, L2)
print 'L1 = ', L1
# Out:
# L1 =  [2, 3, 4]

# %%
def removeDup(L1, L2):
    for e1 in L1[:]:
        if e1 in L2:
            L1.remove(e1)
            
L1=[1,2,3,4]
L2=[1,2,5,6]
removeDup(L1, L2)
print 'L1 = ', L1
# Out:
# L1 =  [3, 4]

# %% [markdown]
# ### string과 list의 차이점
#
# * string과 list는 인덱스를 통해 접근할 수 있는 등 비슷한 점이 많음

# %%
my_string = 'test'
print my_string[0]
# Out:
# t

# %% [markdown]
# * list는 인덱스를 통해 원소를 변화시키는 것이 가능(mutable)
#  * my_list[i] = new_element

# %% [markdown]
# * string은 불가능 (immutable)

# %%
my_string[0] = 'k'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-81a57a54443f> in <module>()
# ----> 1 my_string[0] = 'k'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ### list concatenation

# %%
x = [1, 2, 3]
x.extend([4, 5, 6])   # x is now [1, 2, 3, 4, 5, 6]
print x
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# 만약 x를 변화시키고 싶지 않으면

# %%
x = [1, 2, 3]
y = x + [4, 5, 6]   # y is [1, 2, 3, 4, 5, 6] x는 그대로
print x
print y
# Out:
# [1, 2, 3]
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# * 하나씩 추가할 경우는 append를 많이 씀

# %%
x = [1, 2, 3]
x.append(0)     # x is now [1, 2, 3, 0]
print x
# Out:
# [1, 2, 3, 0]

# %% [markdown]
# ### List comprehension

# %%
squares = [x**2 for x in range(4)]
print squares
# Out:
# [0, 1, 4, 9]

# %%
[(x, y) for x in [1, 2, 3] for y in [3, 1, 4] if x!=y]
# Out:
# [(1, 3), (1, 4), (2, 3), (2, 1), (2, 4), (3, 1), (3, 4)]

# %%
[abs(x) for x in [-1, 2, -3]]
# Out:
# [1, 2, 3]

# %%
from math import pi
[str(round(pi, i)) for i in range(1, 6)]
# Out:
# ['3.1', '3.14', '3.142', '3.1416', '3.14159']

# %%
mixed = [1, 2, 'a', 3, 4.0]
print [x**2 for x in mixed if type(x) == int]
# Out:
# [1, 4, 9]

# %% [markdown]
# ### Tuple - 투플
#
# * Tuple은 list와 매우 비슷함
#   * 단 immutable
#   * 내용을 바꾸는 연산을 제외한 list의 많은 연산을 똑같이 수행 가능
#   * [ ]가 아닌 ( ) 혹은 아무런 괄호 없이 표현

# %%
my_tuple = (1, 2)
my_tuple[1] = 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-57449996a636> in <module>()
#       1 my_tuple = (1, 2)
# ----> 2 my_tuple[1] = 3
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# * 여러 값을 같이 반환할 때 유용

# %%
def sum_product(x, y): return x+y, x*y

# %%
sum_product(2, 3)
# Out:
# (5, 6)

# %% [markdown]
# * 여러 값을 동시에 부여 (list로도 가능)

# %%
x, y = (1, 2)
x, y = y, x     #Python에서 두 변수 값을 swap하는 법
print x, y
# Out:
# 2 1

# %% [markdown]
# ### Example : Tuple

# %%
t1 = ()
t2 = (1, 'two', 3)
t3 = (10,)   # 원소가 하나인 tuple

# %%
print t1
# Out:
# ()

# %%
print t2
# Out:
# (1, 'two', 3)

# %%
print t3
# Out:
# (10,)

# %%
t1 = (1, 'two', 3)
t2 = (t1, 3.25)

# %%
print t2
# Out:
# ((1, 'two', 3), 3.25)

# %%
print (t1 + t2)
# Out:
# (1, 'two', 3, (1, 'two', 3), 3.25)

# %%
print (t1 + t2)[3]
# Out:
# (1, 'two', 3)

# %%
print (t1 + t2)[2:5]
# Out:
# (3, (1, 'two', 3), 3.25)

# %% [markdown]
# ### Example : 공약수

# %%
def findDivisors (n1, n2):
    divisors = ()  #empty tuple
    for i in range(1, min (n1, n2) + 1):
        if n1%i == 0 and n2%i == 0:
            divisors = divisors + (i, )
    return divisors

# %%
divisors = findDivisors(20, 100)
print divisors
# Out:
# (1, 2, 4, 5, 10, 20)

# %% [markdown]
# ### for문과 list의 연계

# %%
my_list = [10, 'hi', -1.2, 'first']

# %%
for x in my_list:
    print x
# Out:
# 10
# hi
# -1.2
# first

# %%
student_list = ['Tom', 'Jack', 'Jane', 'Susan']
student_list.sort()
for student in student_list:
    print student
# Out:
# Jack
# Jane
# Susan
# Tom

# %% [markdown]
# ### enumerate
#
# * enumerate을 이용하여 인덱스와 리스트의 값에 접근

# %%
student_list = ['Tom', 'Jane', 'Susie', 'Chris']
for index, value in enumerate(student_list):
    print index, value
# Out:
# 0 Tom
# 1 Jane
# 2 Susie
# 3 Chris

# %% [markdown]
# * for i in range(len(some_list)):
# &nbsp;&nbsp;&nbsp;&nbsp;do something(i)&nbsp;&nbsp;&nbsp;&nbsp;     # not Pythonic
#
# * for i, _ in enumerate(some_list) :
# &nbsp;&nbsp;&nbsp;&nbsp;do something(i)&nbsp;&nbsp;&nbsp;&nbsp;  # Pythonic

# %% [markdown]
# ### zip
#
# * 두 개 이상의 리스트를 원소 별로 합쳐서 투플들의 리스트로 생성

# %%
x = [1, 2, 3]
y = [4, 5, 6]
zipped = zip(x, y)    # [(1, 4), (2, 5), (3, 6)]
print zipped
# Out:
# [(1, 4), (2, 5), (3, 6)]

# %% [markdown]
# ### String, tuple, list 공통적인 기능
#
# * seq[i] : i번째 원소
# * len(seq) : 길이
# * seq1 + seq2 : 연결
# * n * seq : n번 반복
# * seq[start:end] : 일부
# * e in seq : 만약 e가 seq에 속하면 True, 아니면 False
# * e not in seq : 만약 e가 seq에 속하면 False, 아니면 True
# * for e in seq : 반복문
#
# ### Dictionary
#
# * Dictionary는 list처럼 여러 원소들을 하나의 collection으로 사용
# * List에서는 index를 통하여 원소에 접근하였지만, dictionary에서는 key를 통하여 접근
# * Dictionary의 기본 구조
#   * {key1: element1, key2: element2, … }
# * key는 일반적으로 string이나 숫자를 사용
#   * 예제 – 학생 이름과 점수
#    * {'Tom': 92, 'Jane': 95, 'Amy': 73, 'Nick': 81}
#    * 학생 이름이 key로 사용되었으며, 점수가 값으로 사용됨
#
# ### key를 통한 접근

# %%
scores = {'Tom': 92, 'Jane': 95, 'Amy': 73, 'Nick': 81}

# %%
scores['Tom']
# Out:
# 92

# %%
scores[0]  # error 발생 : index를 통해 접근할 수 없음
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-f79af3d83d2d> in <module>()
# ----> 1 scores[0]  # error 발생 : index를 통해 접근할 수 없음
#
# KeyError: 0

# %% [markdown]
# * list에서와 같이 key를 통하여 원소의 내용을 바꿀 수 있음 (mutable)

# %%
scores['Tom'] = 100
print scores
# Out:
# {'Jane': 95, 'Amy': 73, 'Nick': 81, 'Tom': 100}

# %% [markdown]
# * 기존에 'Robin'이 없으므로 새로운 원소 추가

# %%
scores['Robin'] = 50
print scores
# Out:
# {'Jane': 95, 'Amy': 73, 'Nick': 81, 'Robin': 50, 'Tom': 100}

# %% [markdown]
# * 기존의 원소 제거

# %%
del scores['Nick']
print scores
# Out:
# {'Jane': 95, 'Amy': 73, 'Robin': 50, 'Tom': 100}

# %% [markdown]
# ### Dictionary와 key의 순서

# %%
scores = {'Tom': 92, 'Jane': 95, 'Amy': 73, 'Nick': 81}

# %%
scores.keys()
# Out:
# ['Jane', 'Amy', 'Nick', 'Tom']

# %% [markdown]
# * dictionary는 순서가 정해지지 않음(unordered)

# %%
for key in scores:
    print key, scores[key]
# Out:
# Jane 95
# Amy 73
# Nick 81
# Tom 92

# %% [markdown]
# ### 구조화된 데이터를 dictionary로 표현

# %%
tweet = {
    "user" : "joelgrus",
    "text" : "Data Science is Awesome",
    "retweet_cout" : 100,
    "hashtags" : ["#data", "#science"]
}

tweet_keys = tweet.keys()    #list of keys
tweet_values = tweet.values()   #list of values
tweet_items = tweet.items()   #list of (key, values)

# %%
"user" in tweet_keys  # True but slow
# Out:
# True

# %%
"user" in tweet         # True faster
# Out:
# True

# %%
"joelgrus" in tweet_values  #True
# Out:
# True

# %% [markdown]
# ### Counter
#
# * sequence를 dictionary와 비슷한 형태로 바꾸어 줌

# %%
from collections import Counter
c = Counter([0, 1, 2, 0])
print c
# Out:
# Counter({0: 2, 1: 1, 2: 1})

# %% [markdown]
#   * c의 결과는 다음과 같다 : Counter({0: 2, 1: 1, 2: 1})
#   * 0이 2개, 1이 1개, 2가 1개 있음을 나타냄

# %% [markdown]
# ### Generator and Iterator
#
# * List의 문제 중 하나는 그 길이가 매우 커질 수 있다는 점.
# * 예를 들어 range(1000000)은 백만 개의 원소를 가짐.
# * 때로는 이 데이터를 모두 생성하는 것은 낭비일 수 있음.
# * generator는 for문 등을 이용하여 반복 가능하지만, 그 값들을 생성하는 것은 필요한 경우만 실행.
# * yield를 이용하여 generator를 만드는 방법

# %%
def lazy_range(n):
    i = 0
    while i<n:
        yield i
        i += 1

# %% [markdown]
# ### generator

# %% [markdown]
# for i in lazy_range(10):
# &nbsp;&nbsp;&nbsp;&nbsp;do_something_with(i)

# %% [markdown]
# * Python은 실제로 위와 비슷한 xrange라 불리우는 함수가 있으며,
#   * Python 3에서는 range 자체가 generator를 반환.
# * 다음 세가지는 같은 역할을 함,
#   * for i in range(n):
#   * for i in lazy_range(n):
#   * for i in xrange(n):
#
# * .next()를 이용하여 반복되는 값을 확인
#   * x = lazy_range(10)x.next()x.next()x.next()
#
# ### generator(2)
#
# * 무한 시퀀스를 만들 수도 있다.

# %%
def natural_numbers():
    n = 1
    while True:
        yield n
        n += 1

# %% [markdown]
# * for를 이용한 generator 생성

# %%
lazy_evens_below_20 = (i for i in lazy_range(20) if i%2==0)

# %% [markdown]
# ### dictionary의 iteritem()
#
# * dict는 items() method를 이용하여 key-value 리스트를 반환
# * 한편 dict의 iteritems() method는 yield를 이용하여 key-value 형태의 generator를 반환

# %%
knights = {'gallahad': 'the pure', 'robin': 'the brave'}

# %%
for k, v in knights.iteritems():
    print k, v
# Out:
# gallahad the pure
# robin the brave

# %% [markdown]
# * 같은 역할을 하지만 조금 효율이 떨어질 수 있음:

# %%
for k, v in knights.items():
    print k, v
# Out:
# gallahad the pure
# robin the brave

# %% [markdown]
# ### Sorting - 정렬
#
# * Python 리스트는 sort method를 이용하여 정렬 가능

# %%
x = [4, 1, 2, 3]
y = sorted(x)    # y는 [1, 2, 3, 4], x는 변하지 않음
print x
print y
# Out:
# [4, 1, 2, 3]
# [1, 2, 3, 4]

# %%
x.sort()            # x가 이제 [1, 2, 3, 4]
print x
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# * 응용 : 절대값 기준으로 내림차순으로 정렬

# %%
x = sorted([-4, 1, -2, 3], key=abs, reverse=True)
print x
# Out:
# [-4, 3, -2, 1]

# %% [markdown]
# ### 랜덤 (random) 리스트

# %%
import random
four_uniform_randoms = [random.random() for _ in range(4)]
print four_uniform_randoms
# Out:
# [0.7352675585236194, 0.43451618331587016, 0.02347461071568957, 0.6068031545550642]

# %% [markdown]
# * random.random()은 0과 1사이에서 uniform하게 분포된 랜덤 숫자를 반환
# * _는 다시 사용하지 않을 dummy variable을 표현
#   * x로 바꾸어도 상관없음
# * 랜덤 샘플 추출 (중복 제외)

# %%
lottery_numbers = range(60)
random.sample(lottery_numbers, 6)   # 6개의 랜덤 샘플
# Out:
# [34, 49, 31, 41, 3, 58]

# %% [markdown]
# * 랜덤 선택 (중복 허용)

# %%
four_with_replacement = [random.choice(range(10)) for _ in range(4)]
print four_with_replacement
# Out:
# [4, 2, 5, 9]
